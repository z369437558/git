# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
key = os.environ.get('AZURE_SEARCH_KEY', 'b4f0c8f58865429f8b8e6ff2c6c270a8')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128)>

# %%
 def search_images_bing(key, term, max_images: int = 100, **kwargs):    
     params = {'q':term, 'count':max_images}
     headers = {"Ocp-Apim-Subscription-Key":key}
     search_url = "https://api.bing.microsoft.com/v7.0/images/search"
     response = requests.get(search_url, headers=headers, params=params)
     response.raise_for_status()
     search_results = response.json()    
     return L(search_results['value'])

# %%
results = search_images_bing(key, 'grizzly bear', min_sz=128)
ims = results.attrgot('contentUrl')

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('content_url')
len(ims)
# Out:
# 100

# %%
#hide
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128 at 0x22642DD7100>

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

# %%
# !pip install bing-image-downloader
from bing_image_downloader import downloader
for q in ['grizzly','black bear', 'teddy bear']:
    downloader.download(q, limit=100, output_dir='bears', adult_filter_off=True, force_replace=False, timeout=5)
# Out:
# Requirement already satisfied: bing-image-downloader in c:\users\36943\anaconda3\lib\site-packages (1.0.4)
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Grizzly_Denali_Crop.jpg/1200px-Grizzly_Denali_Crop.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://static.horizontimes.com/wp-content/uploads/2017/06/29102542/Grizzly.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://davidsuzuki.org/wp-content/uploads/2017/04/grizzly-bears-alaska-wildlife-sanctuary-whittier.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.agdaily.com/wp-content/uploads/2018/06/grizzlybear.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cowboystatedaily.com/wp-content/uploads/2020/06/grizzly-ok-to-use-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://animalia-life.com/data_images/grizzly-bear/grizzly-bear5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://wallpapertag.com/wallpaper/full/9/a/0/437133-new-grizzly-bear-backgrounds-1920x1200-for-meizu.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://www.naturephoto-cz.com/fullsize/others/grizzly-bear-215328.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://www.sfu.ca/geog/geog455_2017/Grizzly/images/Grizz5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://wallpapercave.com/wp/wp4087079.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://www.columbiatribune.com/storyimage/MO/20171003/NEWS/171009653/AR/0/AR-171009653.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://4.bp.blogspot.com/-QmwOWiR3ydM/USOj4DBjZSI/AAAAAAAAFBM/bvX4-MmH-tY/s1600/Grizzly_Bear_Info_Images+08.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://cyber-breeze.com/wp-content/uploads/2016/11/silvertip-grizzly-bear.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://denverzoo.org/wp-content/uploads/2018/09/Grizzly-Bear_Thumb.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from http://wildlife.org/wp-content/uploads/2015/08/Grizzly-Bear-Credit-Washington-State-University.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://tailandfur.com/wp-content/uploads/2016/10/20-Fun-Facts-about-Grizzly-Bears-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://www.unilad.co.uk/wp-content/uploads/2015/08/UNILAD-mom-grizzly8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https
maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #99 from http://www.bearessentials.ie/wp-content/uploads/2013/05/Giant-Teddy-Bear.jpg
# [!] Issue getting: http://www.bearessentials.ie/wp-content/uploads/2013/05/Giant-Teddy-Bear.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #99 from https://28zsm21esa5t3fuvrf32xlse-wpengine.netdna-ssl.com/wp-content/uploads/2016/07/Boomer-sitting.png
# [%] File Downloaded !
#
# [%] Downloading Image #100 from https://static.kodajo.com/images/user/fileUp/7a658e687aa0cb3f805ffd19c07e64db.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 100 images.
#
# ===============================================

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bear')
        download_images(dest, urls=results.attrgot('content_url'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#307) [Path('bears/black bear/Image_1.jpg'),Path('bears/black bear/Image_10.jpg'),Path('bears/black bear/Image_100.jpg'),Path('bears/black bear/Image_11.jpg'),Path('bears/black bear/Image_12.jpg'),Path('bears/black bear/Image_13.jpg'),Path('bears/black bear/Image_14.jpg'),Path('bears/black bear/Image_15.jpg'),Path('bears/black bear/Image_16.jpg'),Path('bears/black bear/Image_17.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-166-389107eee051> in <module>
# ----> 1 failed = verify_images(fns)
#       2 failed
#
# ~\anaconda3\lib\site-packages\fastai\vision\utils.py in verify_images(fns)
#      45 def verify_images(fns):
#      46     "Find images in `fns` that can't be opened"
# ---> 47     return L(fns[i] for i,o in enumerate(parallel(verify_image, fns)) if not o)
#      48
#      49 # Cell
#
# ~\anaconda3\lib\site-packages\fastcore\xtras.py in parallel(f, items, n_workers, total, progress, pause, threadpool, timeout, chunksize, *args, **kwargs)
#     358             if total is None: total = len(items)
#     359             r = progress_bar(r, total=total, leave=False)
# --> 360         return L(r)
#     361
#     362 # Cell
#
# ~\anaconda3\lib\site-packages\fastcore\foundation.py in __call__(cls, x, *args, **kwargs)
#     161     def __call__(cls, x=None, *args, **kwargs):
#     162         if not args and not kwargs and x is not None and isinstance(x,cls): return x
# --> 163         return super().__call__(x, *args, **kwargs)
#     164
#     165 # Cell
#
# ~\anaconda3\lib\site-packages\fastcore\foundation.py in __init__(self, items, use_list, match, *rest)
#     171         if items is None: items = []
#     172         if (use_list is not None) or not is_array(items):
# --> 173             items = list(items) if use_list else listify(items)
#     174         if match is not None:
#     175             if is_coll(match): match = len(match)
#
# ~\anaconda3\lib\site-packages\fastcore\basics.py in listify(o)
#      49     if isinstance(o, list): return o
#      50     if isinstance(o, str) or is_array(o): return [o]
# ---> 51     if is_iter(o): return list(o)
#      52     return [o]
#      53
#
# ~\anaconda3\lib\site-packages\fastprogress\fastprogress.py in __iter__(self)
#      45         except Exception as e:
#      46             self.on_interrupt()
# ---> 47             raise e
#      48
#      49     def update(self, val):
#
# ~\anaconda3\lib\site-packages\fastprogress\fastprogress.py in __iter__(self)
#      39         if self.total != 0: self.update(0)
#      40         try:
# ---> 41             for i,o in enumerate(self.gen):
#      42                 if i >= self.total: break
#      43                 yield o
#
# ~\anaconda3\lib\concurrent\futures\process.py in _chain_from_iterable_of_lists(iterable)
#     482     careful not to keep references to yielded objects.
#     483     """
# --> 484     for element in iterable:
#     485         element.reverse()
#     486         while element:
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result_iterator()
#     609                     # Careful not to keep a reference to the popped future
#     610                     if timeout is None:
# --> 611                         yield fs.pop().result()
#     612                     else:
#     613                         yield fs.pop().result(end_time - time.monotonic())
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     437                 raise CancelledError()
#     438             elif self._state == FINISHED:
# --> 439                 return self.__get_result()
#     440             else:
#     441                 raise TimeoutError()
#
# ~\anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
failed.map(Path.unlink);

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path, train='train', valid='test', item_tfms=Resize(224), num_workers=0)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path,, train='train', valid='test', item_tfms=Resize(224), num_workers=0)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.697679</td>
#       <td>0.643217</td>
#       <td>0.295082</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.476425</td>
#       <td>0.158685</td>
#       <td>0.049180</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.331140</td>
#       <td>0.098335</td>
#       <td>0.032787</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.230880</td>
#       <td>0.092977</td>
#       <td>0.049180</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.191172</td>
#       <td>0.093818</td>
#       <td>0.049180</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
#hide_output
#cleaner = ImageClassifierCleaner(learn)
#cleaner

# %%
#hide
#for idx in cleaner.delete(): cleaner.fns[idx].unlink()
#for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')
# Out:
# ('grizzly', TensorImage(1), TensorImage([8.1516e-05, 9.9992e-01, 2.5984e-07]))

# %%
learn_inf.dls.vocab
# Out:
# ['black bear', 'grizzly', 'teddy bear']

# %%
#hide_output
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
#hide_output
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
#hide_output
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 0.9999')

# %%
#hide_output
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-193-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-193-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-193-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-193-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-193-e85f52797c49> in on_click_classify(change)
#       1 def on_click_classify(change):
# ----> 2     img = PILImage.create(btn_upload.data[-1])
#       3     out_pl.clear_output()
#       4     with out_pl: display(img.to_thumb(128,128))
#       5     pred,pred_idx,probs = learn_inf.predict(img)
#
# IndexError: list index out of range

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
#hide_output
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %%
#hide
# !pip install voila
# !jupyter serverextension enable voila --sys-prefix
# Out:
# Requirement already satisfied: voila in c:\users\36943\anaconda3\lib\site-packages (0.2.4)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in c:\users\36943\anaconda3\lib\site-packages (from voila) (0.5.1)
# Requirement already satisfied: nbconvert<7,>=6.0.0 in c:\users\36943\anaconda3\lib\site-packages (from voila) (6.0.7)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in c:\users\36943\anaconda3\lib\site-packages (from voila) (6.1.7)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in c:\users\36943\anaconda3\lib\site-packages (from voila) (1.0.5)
# Requirement already satisfied: nest-asyncio in c:\users\36943\anaconda3\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\36943\anaconda3\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (5.0.5)
# Requirement already satisfied: nbformat>=5.0 in c:\users\36943\anaconda3\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (5.0.8)
# Requirement already satisfied: async-generator in c:\users\36943\anaconda3\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: jinja2>=2.4 in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.11.2)
# Requirement already satisfied: jupyter-core in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (4.6.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: bleach in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: testpath in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.7.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\36943\anaconda3\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: tornado>=4.1 in c:\users\36943\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (6.0.4)
# Requirement already satisfied: pyzmq>=13 in c:\users\36943\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (19.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\36943\anaconda3\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\36943\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (227)
# Requirement already satisfied: prometheus-client in c:\users\36943\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.8.0)
# Requirement already satisfied: ipython-genutils in c:\users\36943\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: Send2Trash in c:\users\36943\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\36943\anaconda3\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\36943\anaconda3\lib\site-packages (from nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\36943\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert<7,>=6.0.0->voila) (1.1.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\36943\anaconda3\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (1.15.0)
# Requirement already satisfied: packaging in c:\users\36943\anaconda3\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: webencodings in c:\users\36943\anaconda3\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\36943\anaconda3\lib\site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.5.7)
# Requirement already satisfied: setuptools in c:\users\36943\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (50.3.0.post20201103)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\36943\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (20.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\36943\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (0.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\36943\anaconda3\lib\site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Enabling: voila
# - Writing config: C:\Users\36943\anaconda3\etc\jupyter
#     - Validating...
#       voila 0.2.4 ok
